# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 639

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'http://api.openweathermap.org/data/2.5/weather?&units=Metric&APPID={weather_api_key}'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}&q={city}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass
      
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ternate
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | araouane
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | lalpur
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | nyazepetrovsk
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | vardo
# Processing Record 17 of Set 1 | okahandja
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 1 | taoudenni
# Processing Record 22 of Set 1 | ulaanbaatar
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | sakaiminato
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | lasa
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | tezu
# Processing Record 33 of Set 1 | wanning
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | kamina
# Processing Record 36 of Set 1 | kotelnich
# Processing Record 37 of Set 1 | rio cuarto
# Processing Record 38 of Set 1 | dawlatabad
# Processing Record 39 of Set 1 | balasheyka
# Processing Record 40 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | port-gentil
# Processing Record 44 of Set 1 | hobyo
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | noumea
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | katherine
# Processing Record 0 of Set 2 | rio gallegos
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | meiktila
# Processing Record 3 of Set 2 | kodinsk
# Processing Record 4 of Set 2 | zeya
# Processing Record 5 of Set 2 | malindi
# Processing Record 6 of Set 2 | kudahuvadhoo
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | saint anthony
# Processing Record 9 of Set 2 | gagino
# Processing Record 10 of Set 2 | gimli
# Processing Record 11 of Set 2 | ngunguru
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | yulara
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | yugorsk
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | grand-lahou
# Processing Record 25 of Set 2 | bundaberg
# Processing Record 26 of Set 2 | praia da vitoria
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | micheweni
# Processing Record 29 of Set 2 | tartus
# Processing Record 30 of Set 2 | aktas
# Processing Record 31 of Set 2 | nabire
# Processing Record 32 of Set 2 | auki
# Processing Record 33 of Set 2 | nakamura
# Processing Record 34 of Set 2 | kifri
# Processing Record 35 of Set 2 | palu
# Processing Record 36 of Set 2 | sechura
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | dwarka
# Processing Record 39 of Set 2 | anadyr
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | east liverpool
# Processing Record 42 of Set 2 | dawson creek
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | iqaluit
# Processing Record 46 of Set 2 | marsa matruh
# Processing Record 47 of Set 2 | akdagmadeni
# Processing Record 48 of Set 2 | spencer
# Processing Record 49 of Set 2 | cape town
# Processing Record 0 of Set 3 | nanortalik
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | nampula
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | marabba
# Processing Record 7 of Set 3 | luanda
# Processing Record 8 of Set 3 | fort nelson
# Processing Record 9 of Set 3 | loviisa
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | naze
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | santa cruz de la palma
# Processing Record 15 of Set 3 | synya
# Processing Record 16 of Set 3 | muli
# Processing Record 17 of Set 3 | plouzane
# Processing Record 18 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | solnechnyy
# Processing Record 22 of Set 3 | khuzhir
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | periam
# Processing Record 27 of Set 3 | kiunga
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | puerto escondido
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | ahipara
# Processing Record 35 of Set 3 | vila
# Processing Record 36 of Set 3 | meulaboh
# Processing Record 37 of Set 3 | walvis bay
# Processing Record 38 of Set 3 | masindi
# Processing Record 39 of Set 3 | gannan
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | caibarien
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 3 | miravci
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | alexandria
# Processing Record 47 of Set 3 | portel
# Processing Record 48 of Set 3 | margate
# Processing Record 49 of Set 3 | namatanai
# Processing Record 0 of Set 4 | beloha
# Processing Record 1 of Set 4 | port hawkesbury
# Processing Record 2 of Set 4 | morristown
# Processing Record 3 of Set 4 | san andres
# Processing Record 4 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | marienburg
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | ambagarh chauki
# Processing Record 9 of Set 4 | pauini
# Processing Record 10 of Set 4 | priamurskiy
# Processing Record 11 of Set 4 | haines junction
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | wanparti
# Processing Record 14 of Set 4 | havelock
# Processing Record 15 of Set 4 | half moon bay
# Processing Record 16 of Set 4 | maragogi
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | chara
# Processing Record 19 of Set 4 | vanimo
# Processing Record 20 of Set 4 | bolgar
# Processing Record 21 of Set 4 | guerrero negro
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | chanika
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | dongsheng
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | te anau
# Processing Record 29 of Set 4 | bonavista
# Processing Record 30 of Set 4 | shakawe
# Processing Record 31 of Set 4 | imbituba
# Processing Record 32 of Set 4 | guaymas
# Processing Record 33 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 4 | nizwa
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | biu
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | imamoglu
# Processing Record 39 of Set 4 | kristiansund
# Processing Record 40 of Set 4 | balkhash
# Processing Record 41 of Set 4 | weatherford
# Processing Record 42 of Set 4 | zhigansk
# Processing Record 43 of Set 4 | hermanus
# Processing Record 44 of Set 4 | shitanjing
# Processing Record 45 of Set 4 | arbazh
# Processing Record 46 of Set 4 | tual
# Processing Record 47 of Set 4 | seymchan
# Processing Record 48 of Set 4 | egvekinot
# Processing Record 49 of Set 4 | griffith
# Processing Record 0 of Set 5 | cibakhaza
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | xiuyan
# Processing Record 5 of Set 5 | mehran
# Processing Record 6 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 5 | kiama
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | comodoro rivadavia
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | motril
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | dukat
# Processing Record 15 of Set 5 | sepolno krajenskie
# Processing Record 16 of Set 5 | cumberland
# Processing Record 17 of Set 5 | vitim
# Processing Record 18 of Set 5 | tilichiki
# Processing Record 19 of Set 5 | beringovskiy
# Processing Record 20 of Set 5 | fare
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | mangaluru
# Processing Record 23 of Set 5 | cockburn town
# Processing Record 24 of Set 5 | yumen
# Processing Record 25 of Set 5 | urengoy
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | praia
# Processing Record 28 of Set 5 | jalu
# Processing Record 29 of Set 5 | havre-saint-pierre
# Processing Record 30 of Set 5 | chunskiy
# Processing Record 31 of Set 5 | port augusta
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | sungairaya
# Processing Record 35 of Set 5 | fengzhen
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | narsaq
# Processing Record 38 of Set 5 | mezen
# Processing Record 39 of Set 5 | hami
# Processing Record 40 of Set 5 | malakal
# Processing Record 41 of Set 5 | qaanaaq
# Processing Record 42 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 5 | itarema
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | ranong
# Processing Record 47 of Set 5 | pangody
# Processing Record 48 of Set 5 | bakchar
# Processing Record 49 of Set 5 | mindelo
# Processing Record 0 of Set 6 | atar
# Processing Record 1 of Set 6 | general pico
# Processing Record 2 of Set 6 | matara
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | parczew
# Processing Record 5 of Set 6 | mount gambier
# Processing Record 6 of Set 6 | mar del plata
# Processing Record 7 of Set 6 | ralivka
# Processing Record 8 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 6 | palaiokhora
# City not found. Skipping...
# Processing Record 10 of Set 6 | aginskoye
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | teknaf
# Processing Record 13 of Set 6 | bafra
# Processing Record 14 of Set 6 | boffa
# Processing Record 15 of Set 6 | union
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | puerto leguizamo
# Processing Record 18 of Set 6 | alamosa
# Processing Record 19 of Set 6 | sao felix do xingu
# Processing Record 20 of Set 6 | biloela
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 23 of Set 6 | nouadhibou
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | nuuk
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | barranca
# Processing Record 31 of Set 6 | cap estate
# Processing Record 32 of Set 6 | atuona
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | bongandanga
# Processing Record 35 of Set 6 | north bend
# Processing Record 36 of Set 6 | mweka
# Processing Record 37 of Set 6 | nome
# Processing Record 38 of Set 6 | mount isa
# Processing Record 39 of Set 6 | muzhi
# Processing Record 40 of Set 6 | saint-augustin
# Processing Record 41 of Set 6 | olafsvik
# Processing Record 42 of Set 6 | codrington
# Processing Record 43 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 6 | mogocha
# Processing Record 45 of Set 6 | bilibino
# Processing Record 46 of Set 6 | ust-nera
# Processing Record 47 of Set 6 | grants pass
# Processing Record 48 of Set 6 | nelson bay
# Processing Record 49 of Set 6 | huarmey
# Processing Record 0 of Set 7 | jian
# Processing Record 1 of Set 7 | inhambane
# Processing Record 2 of Set 7 | mlonggo
# Processing Record 3 of Set 7 | clyde river
# Processing Record 4 of Set 7 | northam
# Processing Record 5 of Set 7 | bend
# Processing Record 6 of Set 7 | fukue
# Processing Record 7 of Set 7 | claremore
# Processing Record 8 of Set 7 | touros
# Processing Record 9 of Set 7 | hays
# Processing Record 10 of Set 7 | ginda
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 7 | tiznit
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | itoman
# Processing Record 16 of Set 7 | stornoway
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | culiacan
# Processing Record 19 of Set 7 | koulikoro
# Processing Record 20 of Set 7 | sungaipenuh
# Processing Record 21 of Set 7 | marawi
# Processing Record 22 of Set 7 | husainabad
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | blagoyevo
# Processing Record 25 of Set 7 | benghazi
# Processing Record 26 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 7 | ereymentau
# Processing Record 28 of Set 7 | walpole
# Processing Record 29 of Set 7 | victoria
# Processing Record 30 of Set 7 | sao joaquim
# Processing Record 31 of Set 7 | cururupu
# Processing Record 32 of Set 7 | klyuchi
# Processing Record 33 of Set 7 | gillette
# Processing Record 34 of Set 7 | riaba
# City not found. Skipping...
# Processing Record 35 of Set 7 | upata
# Processing Record 36 of Set 7 | parana
# Processing Record 37 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 7 | tuktoyaktuk
# Processing Record 39 of Set 7 | itaituba
# Processing Record 40 of Set 7 | ife
# Processing Record 41 of Set 7 | concordia
# Processing Record 42 of Set 7 | xichang
# Processing Record 43 of Set 7 | katsuura
# Processing Record 44 of Set 7 | arawa
# Processing Record 45 of Set 7 | sosnovo
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | timmins
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | kapit
# Processing Record 0 of Set 8 | pueblo
# Processing Record 1 of Set 8 | ye
# City not found. Skipping...
# Processing Record 2 of Set 8 | southbridge
# Processing Record 3 of Set 8 | sampit
# Processing Record 4 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 5 of Set 8 | pontes e lacerda
# Processing Record 6 of Set 8 | preobrazheniye
# Processing Record 7 of Set 8 | juneau
# Processing Record 8 of Set 8 | saryozek
# Processing Record 9 of Set 8 | bethel
# Processing Record 10 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | oistins
# Processing Record 12 of Set 8 | paracuru
# Processing Record 13 of Set 8 | lompoc
# Processing Record 14 of Set 8 | rognan
# Processing Record 15 of Set 8 | plettenberg bay
# Processing Record 16 of Set 8 | forestville
# Processing Record 17 of Set 8 | freeport
# Processing Record 18 of Set 8 | ostrovnoy
# Processing Record 19 of Set 8 | torbay
# Processing Record 20 of Set 8 | honiara
# Processing Record 21 of Set 8 | taiyuan
# Processing Record 22 of Set 8 | abbeville
# Processing Record 23 of Set 8 | san carlos de bariloche
# Processing Record 24 of Set 8 | lorengau
# Processing Record 25 of Set 8 | ancud
# Processing Record 26 of Set 8 | silver city
# Processing Record 27 of Set 8 | pouebo
# Processing Record 28 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 8 | nishihara
# Processing Record 30 of Set 8 | lerwick
# Processing Record 31 of Set 8 | longyearbyen
# Processing Record 32 of Set 8 | mahebourg
# Processing Record 33 of Set 8 | guadalupe victoria
# Processing Record 34 of Set 8 | banyo
# Processing Record 35 of Set 8 | duz
# City not found. Skipping...
# Processing Record 36 of Set 8 | vari
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | suntar
# Processing Record 39 of Set 8 | evensk
# Processing Record 40 of Set 8 | mehamn
# Processing Record 41 of Set 8 | verkhoyansk
# Processing Record 42 of Set 8 | hovd
# Processing Record 43 of Set 8 | safford
# Processing Record 44 of Set 8 | mananara
# Processing Record 45 of Set 8 | grandview
# Processing Record 46 of Set 8 | vawkavysk
# Processing Record 47 of Set 8 | bodden town
# Processing Record 48 of Set 8 | alcaniz
# Processing Record 49 of Set 8 | la sarre
# Processing Record 0 of Set 9 | dinguiraye
# Processing Record 1 of Set 9 | monroe
# Processing Record 2 of Set 9 | naron
# Processing Record 3 of Set 9 | akdepe
# Processing Record 4 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 9 | yamethin
# Processing Record 7 of Set 9 | bluefield
# Processing Record 8 of Set 9 | mizan teferi
# Processing Record 9 of Set 9 | bhinmal
# Processing Record 10 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 9 | sayyan
# Processing Record 12 of Set 9 | sanming
# Processing Record 13 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 9 | sento se
# City not found. Skipping...
# Processing Record 15 of Set 9 | chicama
# Processing Record 16 of Set 9 | grahamstown
# Processing Record 17 of Set 9 | fairview
# Processing Record 18 of Set 9 | maningrida
# Processing Record 19 of Set 9 | gusau
# Processing Record 20 of Set 9 | port hardy
# Processing Record 21 of Set 9 | kaupanger
# Processing Record 22 of Set 9 | kumo
# Processing Record 23 of Set 9 | amazar
# Processing Record 24 of Set 9 | mapiripan
# Processing Record 25 of Set 9 | jamsa
# Processing Record 26 of Set 9 | borovoy
# Processing Record 27 of Set 9 | richards bay
# Processing Record 28 of Set 9 | cidreira
# Processing Record 29 of Set 9 | dunda
# Processing Record 30 of Set 9 | aklavik
# Processing Record 31 of Set 9 | yenagoa
# Processing Record 32 of Set 9 | azle
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | lesnoye
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | tevriz
# Processing Record 37 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 9 | nea kerasia
# Processing Record 39 of Set 9 | solenzo
# Processing Record 40 of Set 9 | matipo
# Processing Record 41 of Set 9 | del rio
# Processing Record 42 of Set 9 | mahibadhoo
# Processing Record 43 of Set 9 | goderich
# Processing Record 44 of Set 9 | westport
# Processing Record 45 of Set 9 | siteki
# Processing Record 46 of Set 9 | mantamados
# Processing Record 47 of Set 9 | am timan
# Processing Record 48 of Set 9 | glogow
# Processing Record 49 of Set 9 | veinticinco de mayo
# Processing Record 0 of Set 10 | nadadores
# Processing Record 1 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 2 of Set 10 | urusha
# Processing Record 3 of Set 10 | kruisfontein
# Processing Record 4 of Set 10 | pochutla
# Processing Record 5 of Set 10 | oga
# Processing Record 6 of Set 10 | caucaia
# Processing Record 7 of Set 10 | mashhad
# Processing Record 8 of Set 10 | padang
# Processing Record 9 of Set 10 | beyneu
# Processing Record 10 of Set 10 | port keats
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 10 | cuiluan
# Processing Record 15 of Set 10 | north platte
# Processing Record 16 of Set 10 | edinburg
# Processing Record 17 of Set 10 | latung
# Processing Record 18 of Set 10 | saint john
# Processing Record 19 of Set 10 | dharampuri
# Processing Record 20 of Set 10 | tiksi
# Processing Record 21 of Set 10 | bima
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | mogwase
# Processing Record 24 of Set 10 | jieshi
# Processing Record 25 of Set 10 | bathsheba
# Processing Record 26 of Set 10 | honningsvag
# Processing Record 27 of Set 10 | krasnoselkup
# Processing Record 28 of Set 10 | salinopolis
# Processing Record 29 of Set 10 | banepa
# Processing Record 30 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 10 | gazli
# Processing Record 32 of Set 10 | puerto madryn
# Processing Record 33 of Set 10 | igrim
# Processing Record 34 of Set 10 | salamiyah
# Processing Record 35 of Set 10 | puro
# Processing Record 36 of Set 10 | oytal
# Processing Record 37 of Set 10 | tyukhtet
# Processing Record 38 of Set 10 | gizo
# Processing Record 39 of Set 10 | puerto cabezas
# Processing Record 40 of Set 10 | atbasar
# Processing Record 41 of Set 10 | kamenskiy
# Processing Record 42 of Set 10 | santa isabel do rio negro
# Processing Record 43 of Set 10 | abu zabad
# Processing Record 44 of Set 10 | dom pedrito
# Processing Record 45 of Set 10 | port hedland
# Processing Record 46 of Set 10 | zhanaozen
# Processing Record 47 of Set 10 | santiago
# Processing Record 48 of Set 10 | korla
# Processing Record 49 of Set 10 | khasan
# Processing Record 0 of Set 11 | tautira
# Processing Record 1 of Set 11 | camana
# Processing Record 2 of Set 11 | wallaceburg
# Processing Record 3 of Set 11 | bud
# Processing Record 4 of Set 11 | gladstone
# Processing Record 5 of Set 11 | kampot
# Processing Record 6 of Set 11 | iraquara
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | champerico
# Processing Record 9 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 10 of Set 11 | muros
# Processing Record 11 of Set 11 | sokoni
# Processing Record 12 of Set 11 | ardabil
# Processing Record 13 of Set 11 | mareeba
# Processing Record 14 of Set 11 | tombouctou
# Processing Record 15 of Set 11 | skibbereen
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | chapais
# Processing Record 18 of Set 11 | biltine
# Processing Record 19 of Set 11 | banda aceh
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | saint-francois
# Processing Record 22 of Set 11 | cam ranh
# Processing Record 23 of Set 11 | ihosy
# Processing Record 24 of Set 11 | lashio
# Processing Record 25 of Set 11 | angoche
# Processing Record 26 of Set 11 | nortelandia
# Processing Record 27 of Set 11 | cahors
# Processing Record 28 of Set 11 | sabha
# Processing Record 29 of Set 11 | baiao
# Processing Record 30 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 11 | pilar
# Processing Record 33 of Set 11 | mpika
# Processing Record 34 of Set 11 | hirara
# Processing Record 35 of Set 11 | matagami
# Processing Record 36 of Set 11 | suhbaatar
# Processing Record 37 of Set 11 | joshimath
# Processing Record 38 of Set 11 | sola
# Processing Record 39 of Set 11 | jinchang
# Processing Record 40 of Set 11 | caceres
# Processing Record 41 of Set 11 | novoagansk
# Processing Record 42 of Set 11 | dingzhou
# Processing Record 43 of Set 11 | sangar
# Processing Record 44 of Set 11 | salcininkai
# Processing Record 45 of Set 11 | dickinson
# Processing Record 46 of Set 11 | dauphin
# Processing Record 47 of Set 11 | sabang
# Processing Record 48 of Set 11 | san roque
# Processing Record 49 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 0 of Set 12 | kununurra
# Processing Record 1 of Set 12 | berlevag
# Processing Record 2 of Set 12 | magrath
# Processing Record 3 of Set 12 | vangaindrano
# Processing Record 4 of Set 12 | turayf
# Processing Record 5 of Set 12 | roald
# Processing Record 6 of Set 12 | chaman
# Processing Record 7 of Set 12 | kloulklubed
# Processing Record 8 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 12 | ocampo
# Processing Record 10 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 11 of Set 12 | indianola
# Processing Record 12 of Set 12 | kirakira
# Processing Record 13 of Set 12 | sept-iles
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | sobolevo
# Processing Record 16 of Set 12 | police
# Processing Record 17 of Set 12 | visby
# Processing Record 18 of Set 12 | placido de castro
# Processing Record 19 of Set 12 | dorado
# Processing Record 20 of Set 12 | matay
# Processing Record 21 of Set 12 | saldanha
# Processing Record 22 of Set 12 | laiwu
# Processing Record 23 of Set 12 | waipawa
# Processing Record 24 of Set 12 | dudinka
# Processing Record 25 of Set 12 | caravelas
# Processing Record 26 of Set 12 | nantucket
# Processing Record 27 of Set 12 | poum
# Processing Record 28 of Set 12 | nicoya
# Processing Record 29 of Set 12 | candelaria
# Processing Record 30 of Set 12 | santo domingo
# Processing Record 31 of Set 12 | kumluca
# Processing Record 32 of Set 12 | shizuishan
# Processing Record 33 of Set 12 | adelaide
# Processing Record 34 of Set 12 | mount vernon
# Processing Record 35 of Set 12 | ryotsu
# Processing Record 36 of Set 12 | barguzin
# Processing Record 37 of Set 12 | piacabucu
# Processing Record 38 of Set 12 | kysyl-syr
# Processing Record 39 of Set 12 | tanout
# Processing Record 40 of Set 12 | todos santos
# Processing Record 41 of Set 12 | bela vista
# Processing Record 42 of Set 12 | svecha
# Processing Record 43 of Set 12 | gornopravdinsk
# Processing Record 44 of Set 12 | pangoa
# Processing Record 45 of Set 12 | abalak
# Processing Record 46 of Set 12 | bose
# Processing Record 47 of Set 12 | pangkalanbuun
# Processing Record 48 of Set 12 | porto empedocle
# Processing Record 49 of Set 12 | sambava
# Processing Record 0 of Set 13 | tromso
# Processing Record 1 of Set 13 | new ulm
# Processing Record 2 of Set 13 | zhuhai
# Processing Record 3 of Set 13 | zell am see
# Processing Record 4 of Set 13 | ketchikan
# Processing Record 5 of Set 13 | rocha
# Processing Record 6 of Set 13 | olecko
# Processing Record 7 of Set 13 | galdar
# Processing Record 8 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 13 | acarau
# Processing Record 10 of Set 13 | vao
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | komarikhinskiy
# Processing Record 13 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 14 of Set 13 | shelburne
# Processing Record 15 of Set 13 | bramming
# Processing Record 16 of Set 13 | carbonia
# Processing Record 17 of Set 13 | grand gaube
# Processing Record 18 of Set 13 | malanje
# Processing Record 19 of Set 13 | orissaare
# Processing Record 20 of Set 13 | tynda
# Processing Record 21 of Set 13 | santa maria
# Processing Record 22 of Set 13 | laguna
# Processing Record 23 of Set 13 | jacareacanga
# Processing Record 24 of Set 13 | sweetwater
# Processing Record 25 of Set 13 | cognac
# Processing Record 26 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 13 | liwale
# Processing Record 28 of Set 13 | okha
# Processing Record 29 of Set 13 | aasiaat
# Processing Record 30 of Set 13 | troitsko-pechorsk
# Processing Record 31 of Set 13 | elliot lake
# Processing Record 32 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 13 | shuiji
# Processing Record 34 of Set 13 | byron bay
# Processing Record 35 of Set 13 | quelimane
# Processing Record 36 of Set 13 | weyburn
# Processing Record 37 of Set 13 | russell
# Processing Record 38 of Set 13 | armacao dos buzios
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
                            
# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      ternate   0.8000  127.4000     27.14        78          96        1.88
# 1  new norfolk -42.7826  147.0587     24.28        52          11        0.93
# 2     araouane  18.9048   -3.5265     19.94        15           1        4.52
# 3      mataura -46.1927  168.8643     18.85        40          58        0.54
# 4    jamestown  42.0970  -79.2353     -0.55        72         100        4.63
#
#   Country        Date
# 0      ID  1674518676
# 1      AU  1674518637
# 2      ML  1674518678
# 3      NZ  1674518678
# 4      US  1674518626

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            ternate   0.8000  127.4000     27.14        78          96
# 1        new norfolk -42.7826  147.0587     24.28        52          11
# 2           araouane  18.9048   -3.5265     19.94        15           1
# 3            mataura -46.1927  168.8643     18.85        40          58
# 4          jamestown  42.0970  -79.2353     -0.55        72         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.88      ID  1674518676
# 1              0.93      AU  1674518637
# 2              4.52      ML  1674518678
# 3              0.54      NZ  1674518678
# 4              4.63      US  1674518626

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind='scatter', x='Lat', y='Max Temp', edgecolors = 'k')


# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature (2023-01-23)')
plt.xlabel('Latitude')
plt.ylabel('Max City Temperature (°C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', edgecolors = 'k')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity (2023-01-23)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', edgecolors = 'k')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Cloudiness (2023-01-23)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', edgecolors = 'k')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed (2023-01-23)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regression_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values*slope+intercept 
    line_eq = "y=" + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r-')
    
    #annotate line equation
    plt.annotate(line_eq, xy=(5,5), xycoords='axes pixels', fontsize=15, color='red')
   
    #print r-value statement
    print(f'The r-value is {rvalue}')

    return slope, intercept, rvalue, pvalue, stderr, regress_values, line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           ternate   0.8000  127.4000     27.14        78          96
# 2          araouane  18.9048   -3.5265     19.94        15           1
# 4         jamestown  42.0970  -79.2353     -0.55        72         100
# 7        butaritari   3.0707  172.7902     26.85        80          88
# 8            lalpur  22.2000   69.9667     14.70        52           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.88      ID  1674518676
# 2              4.52      ML  1674518678
# 4              4.63      US  1674518626
# 7              8.30      KI  1674518680
# 8              4.48      IN  1674518680

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        new norfolk -42.7826  147.0587     24.28        52          11
# 3            mataura -46.1927  168.8643     18.85        40          58
# 5             avarua -21.2078 -159.7750     28.03        74          20
# 6             faanui -16.4833 -151.7500     25.54        76         100
# 9          tuatapere -46.1333  167.6833     16.57        50          24
#
#          Wind Speed Country        Date
# City_ID
# 1              0.93      AU  1674518637
# 3              0.54      NZ  1674518678
# 5              2.57      CK  1674518679
# 6              6.10      PF  1674518679
# 9              2.30      NZ  1674518681

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

regression_plot(x_values, y_values)

# # Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max City Temperature (°C)')

plt.show()
# Out:
# The r-value is -0.801297367254381

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

regression_plot(x_values, y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max City Temperature (°C)')

plt.show()
# Out:
# The r-value is 0.4019316146245037

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is a relatively strong negative association between latitude and max city temperature with an r-value of -.080.  This implies that cities located at a lower positive latitudes correlate to higher max city temperatures and cities located at higher positive latitudes correlate to lower max city temperatures.
#
# In the southern hemisphere, there is only a weak positive association between latitude and max city temperature with an r-value of 0.40.  This implies that cities located at higher negative latitudes weakly correlate to lower max city temperatures and cities located at lower negative latitudes weakly correlate to higher city temperatures.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

regression_plot(x_values, y_values)

# # Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.show()
# Out:
# The r-value is 0.49281256439102544

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

regression_plot(x_values, y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.show()
# Out:
# The r-value is 0.5368782401221885

# %% [markdown]
# **Discussion about the linear relationship:** In both the northern and southern hemispheres there is only a weak positive correlation betweeen latitude and percent humidity, with r-values of 0.49 and 0.53 respectively.
#
# When looking at the plot of latitude vs percent humidity in the northern hemisphere, it appears that the variation in percent humidity is less for higher latitudes than at lower latitudes.  For cities with latitudes of 50 or higher, the percent humidity appears to remain above about 50%.  Whereas when looking at cities with latitudes less than 50, the range of percent humidty values is much greater.
#
# When looking at the plot of latitude vs percent humidity in the southern hemisphere, similar to observations made in the same plot for the northern hemisphere, the variation in percent humidity is less for lower negative latitudes than at higher negative latitudes.  For cities with latitudes from 0 to about -15, the percent humidity appears to remain above about 60%. Where as cities with greater negative latitude values have a greater range in percent humidity values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

regression_plot(x_values, y_values)

# # Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.show()
# Out:
# The r-value is 0.3023907815000629

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

regression_plot(x_values, y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.show()
# Out:
# The r-value is 0.4873701902167658

# %% [markdown]
# **Discussion about the linear relationship:** In both the northern and southern hemispheres there is only a weak positive correlation betweeen latitude and percent humidity, with r-values of 0.30 and 0.49 respectively.
#
# For both the northern and southern hemisphere plots of latitude vs percent cloudiness, there a large distribution of points throughout the plot.  The southern hemisphere plot has a slighlty higher r-value, which results in a slighly higher correlation (when compared to the northern hemisphere values), but the overall correlation is still weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

regression_plot(x_values, y_values)

# # Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

plt.show()
# Out:
# The r-value is -0.04251559175394028

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

regression_plot(x_values, y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

plt.show()
# Out:
# The r-value is -0.3410192767474595

# %% [markdown]
# **Discussion about the linear relationship:** In both the northern and southern hemispheres there is only a weak negative correlation betweeen latitude and percent humidity, with r-values of -0.04 and -0.34 respectively.
#
# For the nothern hemisphere plot of latitude vs wind speed, the correlation is very weak.  Looking at the plot, with the exception of a few outliers, the majority of the wind speeds plotted are below 15m/s, with the vast majority being below 5m/s.
#
# For the southern hemisphere plot of latitude vs wind speed, the correlation is slightly higher than that of the northern hemisphere plot, but is still relatively weak.  Looking at th plot, the majority of the wind speeds plotted are below 6m/s, especially those with latitude values between about -45 and 0.
